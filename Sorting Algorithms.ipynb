# %%
from random import randint

def sortcheck(Func):    #this function is to check if the sorting algorithm works or not
    A = [randint(2,1000) for _ in range(100)]
    B = list (A)
    print 'The initial list is:\n'
    print A
    print '\n\nThe sorted list from usermade function is: \n'
    C = Func(A)
    print C
    print '\n\nSorted List is:\n'
    D = sorted(B)
    print D
    print '\n\nThe sorting works is',D==C

# %%
# selection sort

def selectionsort(L):
    l = len(L)
    for i in range(l-1):
        mn, mi = 10**9, i+1
        for j in range(i,l):
            if L[j] < mn:
                mn = L[j]
                mi = j
        L[i], L[mi] = L[mi], L[i]
    return L

sortcheck(selectionsort)
# Out:
# The initial list is:
#
# [109, 508, 617, 72, 478, 69, 549, 579, 586, 679, 620, 101, 317, 181, 553, 395, 299, 621, 425, 137, 820, 579, 468, 870, 590, 548, 168, 623, 473, 651, 526, 565, 267, 625, 725, 868, 863, 249, 342, 513, 29, 765, 995, 358, 836, 897, 547, 51, 562, 372, 544, 42, 714, 521, 550, 517, 776, 939, 934, 823, 513, 60, 964, 95, 360, 401, 230, 231, 328, 546, 24, 300, 650, 875, 486, 632, 181, 423, 803, 471, 862, 684, 924, 351, 15, 419, 541, 110, 510, 725, 948, 60, 201, 981, 597, 821, 442, 153, 831, 634]
#
#
# The sorted list from usermade function is:
#
# [15, 24, 29, 42, 51, 60, 60, 69, 72, 95, 101, 109, 110, 137, 153, 168, 181, 181, 201, 230, 231, 249, 267, 299, 300, 317, 328, 342, 351, 358, 360, 372, 395, 401, 419, 423, 425, 442, 468, 471, 473, 478, 486, 508, 510, 513, 513, 517, 521, 526, 541, 544, 546, 547, 548, 549, 550, 553, 562, 565, 579, 579, 586, 590, 597, 617, 620, 621, 623, 625, 632, 634, 650, 651, 679, 684, 714, 725, 725, 765, 776, 803, 820, 821, 823, 831, 836, 862, 863, 868, 870, 875, 897, 924, 934, 939, 948, 964, 981, 995]
#
#
# Sorted List is:
#
# [15, 24, 29, 42, 51, 60, 60, 69, 72, 95, 101, 109, 110, 137, 153, 168, 181, 181, 201, 230, 231, 249, 267, 299, 300, 317, 328, 342, 351, 358, 360, 372, 395, 401, 419, 423, 425, 442, 468, 471, 473, 478, 486, 508, 510, 513, 513, 517, 521, 526, 541, 544, 546, 547, 548, 549, 550, 553, 562, 565, 579, 579, 586, 590, 597, 617, 620, 621, 623, 625, 632, 634, 650, 651, 679, 684, 714, 725, 725, 765, 776, 803, 820, 821, 823, 831, 836, 862, 863, 868, 870, 875, 897, 924, 934, 939, 948, 964, 981, 995]
#
#
# The sorting works is True

# %%
# Insertion Sort

def insertionsort(L):
    for i in range(1,len(L)):
        j = i
        k = L[i]
        while j>0 and L[j-1]>k:
            L[j] = L[j-1]
            j -= 1
        L[j]=k
    return L

sortcheck(insertionsort)
# Out:
# The initial list is:
#
# [545, 737, 534, 677, 7, 583, 347, 683, 117, 653, 885, 210, 973, 185, 381, 391, 995, 517, 254, 899, 211, 119, 540, 104, 177, 174, 584, 168, 615, 844, 6, 482, 86, 620, 386, 554, 967, 470, 38, 954, 111, 883, 839, 827, 620, 483, 440, 740, 99, 455, 136, 790, 79, 466, 256, 54, 243, 754, 903, 747, 961, 325, 631, 435, 522, 773, 549, 881, 363, 515, 649, 729, 35, 435, 666, 724, 929, 691, 618, 272, 528, 56, 636, 159, 420, 298, 653, 725, 59, 352, 850, 523, 893, 174, 321, 64, 617, 41, 638, 297]
#
#
# The sorted list from usermade function is:
#
# [6, 7, 35, 38, 41, 54, 56, 59, 64, 79, 86, 99, 104, 111, 117, 119, 136, 159, 168, 174, 174, 177, 185, 210, 211, 243, 254, 256, 272, 297, 298, 321, 325, 347, 352, 363, 381, 386, 391, 420, 435, 435, 440, 455, 466, 470, 482, 483, 515, 517, 522, 523, 528, 534, 540, 545, 549, 554, 583, 584, 615, 617, 618, 620, 620, 631, 636, 638, 649, 653, 653, 666, 677, 683, 691, 724, 725, 729, 737, 740, 747, 754, 773, 790, 827, 839, 844, 850, 881, 883, 885, 893, 899, 903, 929, 954, 961, 967, 973, 995]
#
#
# Sorted List is:
#
# [6, 7, 35, 38, 41, 54, 56, 59, 64, 79, 86, 99, 104, 111, 117, 119, 136, 159, 168, 174, 174, 177, 185, 210, 211, 243, 254, 256, 272, 297, 298, 321, 325, 347, 352, 363, 381, 386, 391, 420, 435, 435, 440, 455, 466, 470, 482, 483, 515, 517, 522, 523, 528, 534, 540, 545, 549, 554, 583, 584, 615, 617, 618, 620, 620, 631, 636, 638, 649, 653, 653, 666, 677, 683, 691, 724, 725, 729, 737, 740, 747, 754, 773, 790, 827, 839, 844, 850, 881, 883, 885, 893, 899, 903, 929, 954, 961, 967, 973, 995]
#
#
# The sorting works is True

# %%
# bubble sort

def bubblesort(L):
    l = len(L)
    for i in range(l-1):
        for j in range(l-i-1):
            if L[j] > L[j+1]:
                L[j], L[j+1] = L[j+1], L[j]
    return L

sortcheck(bubblesort)
# Out:
# The initial list is:
#
# [198, 919, 389, 335, 32, 820, 132, 930, 264, 338, 13, 240, 334, 382, 93, 250, 607, 851, 820, 259, 747, 712, 514, 156, 856, 769, 777, 868, 830, 769, 975, 872, 699, 276, 685, 31, 390, 266, 911, 737, 621, 675, 88, 810, 601, 307, 607, 256, 909, 277, 319, 950, 328, 296, 630, 687, 40, 90, 298, 44, 128, 644, 528, 536, 479, 670, 746, 112, 67, 297, 553, 111, 354, 237, 849, 122, 335, 246, 241, 770, 557, 146, 758, 533, 291, 63, 690, 231, 736, 59, 161, 944, 106, 96, 451, 17, 676, 281, 980, 562]
#
#
# The sorted list from usermade function is:
#
# [13, 17, 31, 32, 40, 44, 59, 63, 67, 88, 90, 93, 96, 106, 111, 112, 122, 128, 132, 146, 156, 161, 198, 231, 237, 240, 241, 246, 250, 256, 259, 264, 266, 276, 277, 281, 291, 296, 297, 298, 307, 319, 328, 334, 335, 335, 338, 354, 382, 389, 390, 451, 479, 514, 528, 533, 536, 553, 557, 562, 601, 607, 607, 621, 630, 644, 670, 675, 676, 685, 687, 690, 699, 712, 736, 737, 746, 747, 758, 769, 769, 770, 777, 810, 820, 820, 830, 849, 851, 856, 868, 872, 909, 911, 919, 930, 944, 950, 975, 980]
#
#
# Sorted List is:
#
# [13, 17, 31, 32, 40, 44, 59, 63, 67, 88, 90, 93, 96, 106, 111, 112, 122, 128, 132, 146, 156, 161, 198, 231, 237, 240, 241, 246, 250, 256, 259, 264, 266, 276, 277, 281, 291, 296, 297, 298, 307, 319, 328, 334, 335, 335, 338, 354, 382, 389, 390, 451, 479, 514, 528, 533, 536, 553, 557, 562, 601, 607, 607, 621, 630, 644, 670, 675, 676, 685, 687, 690, 699, 712, 736, 737, 746, 747, 758, 769, 769, 770, 777, 810, 820, 820, 830, 849, 851, 856, 868, 872, 909, 911, 919, 930, 944, 950, 975, 980]
#
#
# The sorting works is True

# %%
# Merge Sort

def mergesort(L):
    l = len(L)
    if l <= 1:
        return L
    
    A = mergesort(L[:l/2])
    B = mergesort(L[l/2:])
    S = []
    
    a, b = 0, 0
    while a<len(A) and b<len(B):
        if A[a] < B[b]:
            S.append(A[a])
            a += 1
        else:
            S.append(B[b])
            b += 1
    S += A[a:] + B[b:]
    return S

sortcheck(mergesort)
# Out:
# The initial list is:
#
# [662, 698, 427, 651, 659, 286, 584, 468, 94, 553, 837, 343, 85, 427, 417, 369, 49, 330, 421, 488, 181, 690, 625, 946, 206, 223, 436, 689, 512, 881, 266, 945, 767, 518, 659, 178, 179, 343, 66, 887, 442, 456, 432, 496, 823, 234, 725, 935, 138, 258, 220, 980, 560, 412, 13, 735, 149, 373, 703, 905, 149, 883, 700, 693, 658, 95, 367, 506, 536, 341, 981, 273, 267, 126, 703, 711, 261, 961, 145, 733, 352, 222, 27, 103, 783, 523, 110, 427, 846, 708, 197, 758, 670, 350, 12, 442, 159, 825, 230, 386]
#
#
# The sorted list from usermade function is:
#
# [12, 13, 27, 49, 66, 85, 94, 95, 103, 110, 126, 138, 145, 149, 149, 159, 178, 179, 181, 197, 206, 220, 222, 223, 230, 234, 258, 261, 266, 267, 273, 286, 330, 341, 343, 343, 350, 352, 367, 369, 373, 386, 412, 417, 421, 427, 427, 427, 432, 436, 442, 442, 456, 468, 488, 496, 506, 512, 518, 523, 536, 553, 560, 584, 625, 651, 658, 659, 659, 662, 670, 689, 690, 693, 698, 700, 703, 703, 708, 711, 725, 733, 735, 758, 767, 783, 823, 825, 837, 846, 881, 883, 887, 905, 935, 945, 946, 961, 980, 981]
#
#
# Sorted List is:
#
# [12, 13, 27, 49, 66, 85, 94, 95, 103, 110, 126, 138, 145, 149, 149, 159, 178, 179, 181, 197, 206, 220, 222, 223, 230, 234, 258, 261, 266, 267, 273, 286, 330, 341, 343, 343, 350, 352, 367, 369, 373, 386, 412, 417, 421, 427, 427, 427, 432, 436, 442, 442, 456, 468, 488, 496, 506, 512, 518, 523, 536, 553, 560, 584, 625, 651, 658, 659, 659, 662, 670, 689, 690, 693, 698, 700, 703, 703, 708, 711, 725, 733, 735, 758, 767, 783, 823, 825, 837, 846, 881, 883, 887, 905, 935, 945, 946, 961, 980, 981]
#
#
# The sorting works is True

# %%
# Merge Sort with Insertion SOrt

def mergeinsertionsort(L):
    l = len(L)
    if l <= 43:
        return insertionsort(L)
    
    A = mergesort(L[:l/2])
    B = mergesort(L[l/2:])
    S = []
    
    a, b = 0, 0
    while a<len(A) and b<len(B):
        if A[a] < B[b]:
            S.append(A[a])
            a += 1
        else:
            S.append(B[b])
            b += 1
    S += A[a:] + B[b:]
    return S

sortcheck(mergeinsertionsort)
# Out:
# The initial list is:
#
# [661, 40, 508, 3, 78, 989, 420, 652, 807, 846, 400, 29, 546, 745, 177, 504, 842, 466, 421, 499, 596, 610, 225, 587, 270, 353, 210, 560, 226, 493, 104, 990, 497, 931, 720, 285, 40, 271, 485, 858, 535, 201, 74, 499, 410, 148, 399, 535, 822, 899, 579, 200, 458, 913, 753, 425, 298, 644, 830, 74, 93, 27, 781, 268, 752, 997, 830, 710, 965, 509, 273, 452, 61, 802, 622, 795, 343, 335, 218, 509, 722, 212, 948, 909, 278, 620, 655, 206, 481, 106, 27, 376, 586, 368, 517, 857, 165, 231, 526, 178]
#
#
# The sorted list from usermade function is:
#
# [3, 27, 27, 29, 40, 40, 61, 74, 74, 78, 93, 104, 106, 148, 165, 177, 178, 200, 201, 206, 210, 212, 218, 225, 226, 231, 268, 270, 271, 273, 278, 285, 298, 335, 343, 353, 368, 376, 399, 400, 410, 420, 421, 425, 452, 458, 466, 481, 485, 493, 497, 499, 499, 504, 508, 509, 509, 517, 526, 535, 535, 546, 560, 579, 586, 587, 596, 610, 620, 622, 644, 652, 655, 661, 710, 720, 722, 745, 752, 753, 781, 795, 802, 807, 822, 830, 830, 842, 846, 857, 858, 899, 909, 913, 931, 948, 965, 989, 990, 997]
#
#
# Sorted List is:
#
# [3, 27, 27, 29, 40, 40, 61, 74, 74, 78, 93, 104, 106, 148, 165, 177, 178, 200, 201, 206, 210, 212, 218, 225, 226, 231, 268, 270, 271, 273, 278, 285, 298, 335, 343, 353, 368, 376, 399, 400, 410, 420, 421, 425, 452, 458, 466, 481, 485, 493, 497, 499, 499, 504, 508, 509, 509, 517, 526, 535, 535, 546, 560, 579, 586, 587, 596, 610, 620, 622, 644, 652, 655, 661, 710, 720, 722, 745, 752, 753, 781, 795, 802, 807, 822, 830, 830, 842, 846, 857, 858, 899, 909, 913, 931, 948, 965, 989, 990, 997]
#
#
# The sorting works is True

# %%
# Quick Sort

from random import choice
def quicksort1(L):
    if len(L) <= 1:
        return L
    k = choice(L)
    A, B, C = [], [], []
    for i in L:
        if i < k:
            A.append(i)
        elif i == k:
            B.append(i)
        elif i > k:
            C.append(i)
    return quicksort1(A) + B + quicksort1(C)


sortcheck(quicksort1)
# Out:
# The initial list is:
#
# [622, 407, 950, 402, 132, 987, 577, 259, 830, 900, 765, 91, 946, 982, 643, 635, 473, 613, 581, 671, 943, 890, 42, 989, 310, 508, 231, 328, 762, 558, 707, 289, 917, 652, 164, 826, 419, 71, 320, 971, 58, 844, 26, 304, 227, 295, 441, 396, 153, 676, 789, 147, 197, 982, 333, 953, 816, 344, 552, 486, 845, 243, 938, 706, 134, 908, 353, 607, 681, 108, 826, 403, 772, 99, 166, 325, 764, 8, 370, 221, 327, 719, 343, 666, 276, 613, 591, 697, 95, 354, 356, 70, 79, 231, 820, 523, 90, 471, 47, 299]
#
#
# The sorted list from usermade function is:
#
# [8, 26, 42, 47, 58, 70, 71, 79, 90, 91, 95, 99, 108, 132, 134, 147, 153, 164, 166, 197, 221, 227, 231, 231, 243, 259, 276, 289, 295, 299, 304, 310, 320, 325, 327, 328, 333, 343, 344, 353, 354, 356, 370, 396, 402, 403, 407, 419, 441, 471, 473, 486, 508, 523, 552, 558, 577, 581, 591, 607, 613, 613, 622, 635, 643, 652, 666, 671, 676, 681, 697, 706, 707, 719, 762, 764, 765, 772, 789, 816, 820, 826, 826, 830, 844, 845, 890, 900, 908, 917, 938, 943, 946, 950, 953, 971, 982, 982, 987, 989]
#
#
# Sorted List is:
#
# [8, 26, 42, 47, 58, 70, 71, 79, 90, 91, 95, 99, 108, 132, 134, 147, 153, 164, 166, 197, 221, 227, 231, 231, 243, 259, 276, 289, 295, 299, 304, 310, 320, 325, 327, 328, 333, 343, 344, 353, 354, 356, 370, 396, 402, 403, 407, 419, 441, 471, 473, 486, 508, 523, 552, 558, 577, 581, 591, 607, 613, 613, 622, 635, 643, 652, 666, 671, 676, 681, 697, 706, 707, 719, 762, 764, 765, 772, 789, 816, 820, 826, 826, 830, 844, 845, 890, 900, 908, 917, 938, 943, 946, 950, 953, 971, 982, 982, 987, 989]
#
#
# The sorting works is True

# %%
# In Place Quick Sort

def quicksort(L, start = 0, end = None):
    if end == None:
        end = len(L)
    if end - start <= 1:
        return
    #print L[start: end]
    a, b = start+1, start+1
    k = L[start]
    while b < end:
        if L[b] <= k:
            L[a], L[b] = L[b], L[a]
            a += 1
        b += 1
    L[start], L[a-1] = L[a-1], L[start]
    a -= 1
    quicksort (L, start, a)
    quicksort (L, a+1, end)
    return L
    
sortcheck(quicksort)
# Out:
# The initial list is:
#
# [183, 925, 402, 208, 328, 664, 973, 439, 500, 17, 848, 692, 106, 254, 700, 135, 544, 691, 853, 129, 916, 831, 649, 636, 369, 597, 437, 231, 743, 958, 692, 569, 795, 279, 550, 459, 478, 40, 826, 277, 5, 279, 208, 767, 973, 902, 697, 683, 647, 704, 126, 594, 102, 428, 157, 914, 654, 964, 203, 83, 853, 711, 906, 797, 809, 204, 48, 204, 803, 572, 269, 107, 917, 563, 279, 693, 571, 828, 972, 655, 522, 917, 796, 513, 687, 669, 637, 887, 137, 812, 992, 292, 599, 534, 820, 159, 356, 12, 583, 310]
#
#
# The sorted list from usermade function is:
#
# [5, 12, 17, 40, 48, 83, 102, 106, 107, 126, 129, 135, 137, 157, 159, 183, 203, 204, 204, 208, 208, 231, 254, 269, 277, 279, 279, 279, 292, 310, 328, 356, 369, 402, 428, 437, 439, 459, 478, 500, 513, 522, 534, 544, 550, 563, 569, 571, 572, 583, 594, 597, 599, 636, 637, 647, 649, 654, 655, 664, 669, 683, 687, 691, 692, 692, 693, 697, 700, 704, 711, 743, 767, 795, 796, 797, 803, 809, 812, 820, 826, 828, 831, 848, 853, 853, 887, 902, 906, 914, 916, 917, 917, 925, 958, 964, 972, 973, 973, 992]
#
#
# Sorted List is:
#
# [5, 12, 17, 40, 48, 83, 102, 106, 107, 126, 129, 135, 137, 157, 159, 183, 203, 204, 204, 208, 208, 231, 254, 269, 277, 279, 279, 279, 292, 310, 328, 356, 369, 402, 428, 437, 439, 459, 478, 500, 513, 522, 534, 544, 550, 563, 569, 571, 572, 583, 594, 597, 599, 636, 637, 647, 649, 654, 655, 664, 669, 683, 687, 691, 692, 692, 693, 697, 700, 704, 711, 743, 767, 795, 796, 797, 803, 809, 812, 820, 826, 828, 831, 848, 853, 853, 887, 902, 906, 914, 916, 917, 917, 925, 958, 964, 972, 973, 973, 992]
#
#
# The sorting works is True
